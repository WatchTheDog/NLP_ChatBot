# %% [markdown]
# # Check Emotion Labeled Dataset
#
# The main objective of this notebook is to show the output dataset from the sentiment analysis model

# %%
import os
import pandas as pd
from pathlib import Path

# %%
dataset_path = Path('C:/Users/Timo/Source/Repos/NLP/NLP_ChatBot/datasets/sentiment_analysis/dataset.csv').resolve()

# %%
dataset = pd.read_csv(dataset_path)

# %%
dataset.head()
# Out:
#    label                   id                 date           user  \
# 0  anger  1335535577547104257  2020-12-06 10:44:29         frgbju
# 1  anger  1335529583060393985  2020-12-06 10:20:40  supersoulstar
# 2  anger  1335520563633262593  2020-12-06 09:44:49     VOGUEPRlNT
# 3  anger  1335392769313972225  2020-12-06 01:17:01   MahanBethany
# 4  anger  1335385811752259585  2020-12-06 00:49:22      KentPiano
#
#                                                 text
# 0  @piersmorgan And I am treated like a pariah, h...
# 1  @FedEx @FedExHelp @FedExEurope @FedExOffice @f...
# 2  DYNAMITE WON #carats #seventeen #svt #dance #a...
# 3  @BlankStevem @RonColeman @RepMattGaetz @NYYRC ...
# 4  A grand for a closed pub! An insult. Spitting ...

# %%
import seaborn as sns

# %% [markdown]
# ## Label count
#
# Check the count of each label

# %%
sns.countplot(x='label', data=dataset)

# %% [markdown]
# ## Text length
#
# Check the length of the tweets

# %%
sns.distplot(dataset.text.apply(lambda text: len(text)), bins=30)

# %% [markdown]
# ## Word count
#
# Check the word count

# %%
sns.distplot(dataset.text.apply(lambda text: len(text.split())), bins=10)
